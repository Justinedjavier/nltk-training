# %%
import tensorflow as tf

# %%
#placeholder for input
x = tf.placeholder(dtype=tf.float32)

# %%
#define the computational graph
y = tf.pow((2 * x), 2)+(2 * x) + 1

# %%
#initialize the variables
init_op = tf.global_variables_initializer()

# %%
#create a session
sess = tf.Session()

# %%
#run the computational graph with input 10 to x
value = sess.run(y, feed_dict={x: 10})

# %%
print(value)
# Out:
# 421.0

# %%
#create random  variable
weights = tf.Variable(tf.random_normal(shape=[10]))

# %%
sess.run(tf.global_variables_initializer())

# %%
sess.run(weights)
# Out:
# array([ 1.1250082 , -0.45962802, -1.0146993 , -0.0443461 , -0.60476863,
#        -0.49439296,  1.0661944 ,  0.06907585,  1.4669716 ,  0.23584601],
#       dtype=float32)
